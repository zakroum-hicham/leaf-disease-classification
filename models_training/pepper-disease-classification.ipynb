# %%
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
# Out:
# 2024-08-15 16:14:25.812642: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-15 16:14:25.812744: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-15 16:14:25.945023: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
directory = "models_training\PlantVillage"

main_classes = [
 'Pepper__bell___Bacterial_spot',
 'Pepper__bell___healthy']

dataset = keras.preprocessing.image_dataset_from_directory(
    directory,
    class_names=main_classes
)
# Out:
# Found 2475 files belonging to 2 classes.

# %%
dataset.class_names
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy']

# %%
len(dataset)
# Out:
# 78

# %%
plt.figure(figsize=(12,12))
for image_batch, label_batch in dataset.take(1):
    for i  in range(12):
        image = image_batch[i].numpy().astype("uint8")
        label = label_batch[i].numpy()
        ax = plt.subplot(4,3,i+1)
        plt.imshow(image)
        plt.title(f"Label:  {main_classes[label]}")  
        plt.axis('off')

# %% [markdown]
# ## splitting the dataset

# %%
def train_test_split(dataset,train_split=0.8,valid_split=0.1,shuffle=True):
    if shuffle:
        dataset.shuffle(2000)
    dataset_size = len(dataset)
    train_size = int(train_split * dataset_size)
    valid_size =  int(valid_split * dataset_size)
    test_size =  dataset_size - (train_size + valid_size)


    train_dataset = dataset.take(train_size)
    valid_dataset = dataset.skip(train_size).take(valid_size)
    test_dataset = dataset.skip(train_size + valid_size)

    return train_dataset,valid_dataset,test_dataset

# %%
train_dataset,valid_dataset,test_dataset  = train_test_split(dataset)

# %%
len(train_dataset)
# Out:
# 62

# %%
import tensorflow as tf
train_dataset = train_dataset.shuffle(buffer_size=len(train_dataset)).prefetch(buffer_size=tf.data.AUTOTUNE)
valid_dataset = valid_dataset.shuffle(buffer_size=len(valid_dataset)).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = test_dataset.shuffle(buffer_size=len(test_dataset)).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### preprocessing

# %%
image_size = 256

resize_rescale = keras.Sequential([
    keras.layers.Resizing(image_size,image_size),
    keras.layers.Rescaling(1./255)
])

data_augmentation = keras.Sequential([
    # keras.layers.RandomBrightness(factor=0.2),
    # keras.layers.RandomFlip("horizontal_and_vertical"),
    keras.layers.RandomRotation(0.2),
    keras.layers.RandomZoom(.5,.2)
])

# %%
batch_size, channels = 32,3
model = keras.models.Sequential([
    resize_rescale,
    data_augmentation,
    keras.layers.Conv2D(128,(3,3),activation="relu",input_shape=(batch_size,image_size,image_size,channels)),
    keras.layers.MaxPooling2D((3,3)),

    keras.layers.Conv2D(128,(3,3),activation="relu"),
    keras.layers.MaxPooling2D((3,3)),

    keras.layers.Conv2D(64,(3,3),activation="relu"),
    keras.layers.MaxPooling2D((3,3)),

    keras.layers.Conv2D(64,(3,3),activation="relu"),
    keras.layers.MaxPooling2D((3,3)),

    keras.layers.Flatten(),
    keras.layers.Dense(32,activation="relu"),
    keras.layers.Dense(len(main_classes),activation="softmax")

])
model.build()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# %%
with tf.device("/device:GPU:0"):
    history = model.fit(
    train_dataset,
    epochs=30,
    batch_size=32,
    verbose=1,  
    validation_data=valid_dataset
    )
# Out:
# Epoch 1/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.6354 - loss: 0.6457 - val_accuracy: 0.8616 - val_loss: 0.3362
# Epoch 2/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9082 - loss: 0.2493 - val_accuracy: 0.9330 - val_loss: 0.1597
# Epoch 3/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9340 - loss: 0.1671 - val_accuracy: 0.8929 - val_loss: 0.3349
# Epoch 4/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9576 - loss: 0.1539 - val_accuracy: 0.9062 - val_loss: 0.2383
# Epoch 5/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.9709 - loss: 0.0880 - val_accuracy: 0.9107 - val_loss: 0.2998
# Epoch 6/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9754 - loss: 0.0603 - val_accuracy: 0.9018 - val_loss: 0.2947
# Epoch 7/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9797 - loss: 0.0866 - val_accuracy: 0.9241 - val_loss: 0.1551
# Epoch 8/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9926 - loss: 0.0325 - val_accuracy: 0.9777 - val_loss: 0.0553
# Epoch 9/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9845 - loss: 0.0407 - val_accuracy: 0.8616 - val_loss: 0.5401
# Epoch 10/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9821 - loss: 0.0855 - val_accuracy: 0.9554 - val_loss: 0.0924
# Epoch 11/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9942 - loss: 0.0210 - val_accuracy: 0.9866 - val_loss: 0.0256
# Epoch 12/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9932 - loss: 0.0209 - val_accuracy: 0.9955 - val_loss: 0.0095
# Epoch 13/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9932 - loss: 0.0841 - val_accuracy: 0.9955 - val_loss: 0.0077
# Epoch 14/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9844 - loss: 0.0466 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 15/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9939 - loss: 0.0359 - val_accuracy: 0.9955 - val_loss: 0.0091
# Epoch 16/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9882 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 17/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9911 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 18/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9977 - loss: 0.0134 - val_accuracy: 0.9955 - val_loss: 0.0120
# Epoch 19/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9955 - loss: 0.0154 - val_accuracy: 0.9955 - val_loss: 0.0179
# Epoch 20/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9977 - loss: 0.0099 - val_accuracy: 0.9777 - val_loss: 0.0525
# Epoch 21/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9945 - loss: 0.0134 - val_accuracy: 0.9866 - val_loss: 0.0305
# Epoch 22/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9931 - loss: 0.0199 - val_accuracy: 0.9955 - val_loss: 0.0616
# Epoch 23/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9883 - loss: 0.0408 - val_accuracy: 0.9955 - val_loss: 0.0443
# Epoch 24/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.9915 - loss: 0.0273 - val_accuracy: 0.9955 - val_loss: 0.0063
# Epoch 25/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9951 - loss: 0.0154 - val_accuracy: 0.9688 - val_loss: 0.0606
# Epoch 26/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9904 - loss: 0.0315 - val_accuracy: 0.9911 - val_loss: 0.0148
# Epoch 27/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9913 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 28/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.9955 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 29/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.9957 - loss: 0.0188 - val_accuracy: 0.9777 - val_loss: 0.0669
# Epoch 30/30
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.9960 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0036

# %%
model.evaluate(test_dataset)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9905 - loss: 0.0126
# [0.007169903721660376, 0.9962546825408936]

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

# %%
plt.figure(figsize=(12,12))
epochs_range  =range(history.params["epochs"])
plt.subplot(1,2,1)
plt.plot(epochs_range,accuracy,label="Training Accuracy")
plt.plot(epochs_range,val_accuracy,label="Validation Accuracy")
plt.title("Training & Validation accuracy")

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label="Training loss")
plt.plot(epochs_range,val_loss,label="Validation loss")
plt.title("Training & Validation loss")
# Out:
# Text(0.5, 1.0, 'Training & Validation loss')

# %%
model.save("/kaggle/working/pepper.keras")

# %%
model = keras.models.load_model("/kaggle/working/pepper.keras")

# %%
import numpy as np
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = main_classes[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = main_classes[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
